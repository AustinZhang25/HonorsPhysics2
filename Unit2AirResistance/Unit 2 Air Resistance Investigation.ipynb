# %% [markdown]
# # Day 1 Sep 18 2023

# %%
import matplotlib.pyplot as plt
import math
import numpy as np
import pandas as pd

# %%
i_Current = 100
i_rate = 0.05
i_List = []
i_Next = i_Current

# %%
for i in range (1,10):
    i_Next = i_Current + i_Current*i_rate
    i_List.append(i_Current)
    i_Current = i_Next
    plt.plot(i, i_Current, "o", color = "green")

# %% [markdown]
# # Day 2 Sep 20 2023

# %% [markdown]
# ## Our Plan:
#
# 1. 2D motion no air resistance
# 2. 1D motion with air resistance
# 3. 2D motion with air resistance

# %% [markdown]
# ### 2D motion no air resistance (Euler's)

# %%
t = [];
t.append(0);
time = 0;
dt = 0.05;
A = -9.8;
Vx = [];
Vx.append(0);
X = [];
Y = [];
Vy = [];
XCurrent = 0.0
YCurrent = 0.0
X.append(0);
Y.append(0)
theta = math.pi/4;

# %%
V0 = 10
VxCurrent = V0*math.cos(theta)
Vx.append(VxCurrent)
VyCurrent = V0*math.sin(theta)

# %%
while YCurrent >= 0:
    time += dt
    t.append(time)
    Vx.append(VxCurrent)
    XCurrent += VxCurrent*dt
    X.append(XCurrent)
    VyCurrent += A*dt
    Vy.append(VyCurrent)
    YCurrent+=VyCurrent*dt
    Y.append(YCurrent)
plt.plot(X, Y, "o", color = "green")

# %% [markdown]
# ### Comparing Model To Data

# %% [markdown]
# #### Finding Velocity Initial of Launcher

# %% [markdown]
# y = VInit*t + 1/2 at^2
#
# 0 = VInit*t + -4.9at^2
#
# find t
#
# Maybe not a good idea

# %%
Y = 0 
Vy = 0
dT = 0.05
A = -9.8

# %%
while Y >= 0:
    Vy +=

# %% [markdown]
# # day 3 Sep 26 2023

# %% [markdown]
# We take data, but we used video analysis. Video analysis is not very accurate i think.

# %% [markdown]
# Velocity Graph

# %% [markdown]
# # 1 D Model(Euler's method)

# %%
import matplotlib.pyplot as plt

# %%
mass = 3.66
a = 0.0
v = 1.0*(math.sin(math.pi/4))
t = 0.0
Fair = 0.0
Fnet = -3.66
W = -35.686
tList = [0]
yPosList = [0]
yPos = 0
vList = [0]
delta_t = 0.01

# %%
import math
for i in range (300):
    Fair
    print (t)
    print (i)
    print (a)
    print (v)
    print (Fair)
    print (W+Fair)
    print('')
    t += delta_t
    v += (delta_t*a)
    #v = (t*a)
    a = (W + Fair)/mass
    Fair = 19.226*(abs(v)**2.719)
    tList.append(t)
    yPos += (delta_t*v)
    yPosList.append(yPos)
    vList.append(v)
    plt.plot(tList, vList, "o", color = "green")
# Out:
# 0.0
# 0
# 0.0
# 0.7071067811865475
# 0.0
# -35.686
#
# 0.01
# 1
# -9.750273224043715
# 0.0
# 0.0
# -35.686
#
# 0.02
# 2
# -9.750273224043715
# -0.1950054644808743
# 0.22569718201689648
# -35.460302817983106
#
# 0.03
# 3
# -9.688607327317788
# -0.29250819672131145
# 0.6797015652241787
# -35.00629843477582
#
# 0.04
# 4
# -9.564562413873174
# -0.38754429309271154
# 1.4606113717283955
# -34.2253886282716
#
# 0.05
# 5
# -9.351199078762733
# -0.4782281206936587
# 2.5871213600597343
# -33.09887863994027
#
# 0.060000000000000005
# 6
# -9.043409464464553
# -0.561071944725764
# 3.994573202197983
# -31.691426797802016
#
# 0.07
# 7
# -8.658859780820222
# -0.6330386625125187
# 5.545972953960643
# -30.140027046039357
#
# 0.08
# 8
# -8.234980067223868
# -0.6927087824656178
# 7.085104734883727
# -28.60089526511627
#
# 0.09
# 9
# -7.814452258228489
# -0.7411482060501481
# 8.514532368867727
# -27.171467631132273
#
# 0.09999999999999999
# 10
# -7.423898259872206
# -0.7814452258228489
# ...

# %%
mass = 3.66
a = 0.0
v = 1.0*(math.cos(math.pi/4))
#initial velocity or else x won't move since no gravity in x direction
t = 0.0
Fair = 0.0
tList = [0]
xPos = 0
xPosList = [0]
vList = [0]
delta_t = 0.01

# %%
import math
for i in range (3000):
    print (t)
    print (i)
    print (a)
    print (v)
    print (Fair)
    print('')
    t += delta_t
    v -= (delta_t*a)
    #v = (t*a)
    a = Fair/mass
    Fair = 19.226*(abs(v)**2.719)
    tList.append(t)
    xPos += (delta_t*v)
    xPosList.append(xPos)
    vList.append(v)
    plt.plot(tList, vList, "o", color = "green")
# Out:
# 0.0
# 0
# 0.0
# 0.7071067811865476
# 0.0
#
# 0.01
# 1
# 0.0
# 0.7071067811865476
# 7.492705428162902
#
# 0.02
# 2
# 2.0471872754543448
# 0.7071067811865476
# 7.492705428162902
#
# 0.03
# 3
# 2.0471872754543448
# 0.6866349084320041
# 6.917459152600762
#
# 0.04
# 4
# 1.8900161619127764
# 0.6661630356774607
# 6.370952996954393
#
# 0.05
# 5
# 1.7406975401514733
# 0.6472628740583329
# 5.891384312261614
#
# 0.060000000000000005
# 6
# 1.6096678448802224
# 0.6298558986568182
# 5.470484140110711
#
# 0.07
# 7
# 1.4946677978444567
# 0.613759220208016
# 5.0986544527033555
#
# 0.08
# 8
# 1.3930749870774195
# 0.5988125422295714
# 4.768072636783766
#
# 0.09
# 9
# 1.3027520865529416
# 0.5848817923587972
# 4.472466607754688
#
# 0.09999999999999999
# 10
# 1.2219854119548328
# 0.5718542714932678
# 4.206761178923235
#
# 0.10999999999999999
# 11
# 1.1493883002522498
# 0.5596344173737196
# 3.966806754905214
#
# 0.11999999999999998
# 12
# 1.0838269822145392
# 0.548140534371197
# 3.74917804637355
#
# ...

# %%
    plt.plot(xPosList, yPosList,"o",color = "green")

# %%
import matplotlib.pyplot as plt
import math
import numpy as np
import pandas as pd
